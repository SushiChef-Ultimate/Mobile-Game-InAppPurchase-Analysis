# %%
# Pips and imports
# !pip install numpy pandas matplotlib seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: numpy in c:\users\susha\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in c:\users\susha\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\susha\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\susha\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\susha\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\susha\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\susha\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\susha\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\susha\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Setup
MobileGame_DF = pd.read_csv("mobile_game_inapp_purchases.csv")
MobileGame_DF = MobileGame_DF.dropna(axis=0)
MobileGame_DF.describe()
# Out:
#                Age  SessionCount  AverageSessionLength  InAppPurchaseAmount  \
# count  2612.000000   2612.000000           2612.000000          2612.000000
# mean     33.416156     10.043645             20.072400           104.465088
# std      11.999914      3.121136              8.557648           464.663512
# min      13.000000      1.000000              5.010000             0.000000
# 25%      23.000000      8.000000             12.680000             5.940000
# 50%      33.000000     10.000000             20.365000            11.895000
# 75%      44.000000     12.000000             27.365000            17.780000
# max      54.000000     22.000000             34.990000          4964.450000
#
#        FirstPurchaseDaysAfterInstall
# count                    2612.000000
# mean                       15.414625
# std                         8.933860
# min                         0.000000
# 25%                         8.000000
# 50%                        16.000000
# 75%                        23.000000
# max                        30.000000

# %% [markdown]
# Preprocessing:
#     We set up MobileGame_DF as a pandas dataframe of "mobile_game_inapp_purchases.csv".
#     our main preprocessing step is to drop null columns. Since nulls only make up around 2-5% of records, dropping them wont really affect our data, and help with ensuring that only properly collected and "complete" records make it into our visualizations.

# %%
print(MobileGame_DF.columns)
# Out:
# Index(['UserID', 'Age', 'Gender', 'Country', 'Device', 'GameGenre',
#        'SessionCount', 'AverageSessionLength', 'SpendingSegment',
#        'InAppPurchaseAmount', 'FirstPurchaseDaysAfterInstall', 'PaymentMethod',
#        'LastPurchaseDate'],
#       dtype='object')

# %%
# Average spending by gender
sns.barplot(data=MobileGame_DF, x='Gender', y='InAppPurchaseAmount', hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='InAppPurchaseAmount'>

# %%
# 3 seperate bar graphs for each gender using catplot
sns.catplot(
    data=MobileGame_DF,
    x='SpendingSegment',
    kind='count',
    col='Gender', # Creates the 3 seperate barplots seperating by gender
    height=4,
    aspect=0.8,
    hue = 'Gender'
)

plt.show()

# %% [markdown]
# IMPORTANT CONTEXT : People who spend money on mobile games are seperted into 3 categories
#     Minnow : Light and occasional spending
#     Dolphin : Consistent and moderate spending
#     Whale : Very frequent and heavy spending

# %%
# Box plot for when first purchase is made after install by gender
plt.figure(figsize=(16, 6))
plt.xticks(rotation=30)
sns.boxplot(data=MobileGame_DF, x='Gender', y='FirstPurchaseDaysAfterInstall', hue='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='FirstPurchaseDaysAfterInstall'>

# %%
# Average spending by country
plt.figure(figsize=(18, 6))
plt.xticks(rotation=45)
sns.barplot(data=MobileGame_DF, x='Country', y='InAppPurchaseAmount', hue='Country')
# Out:
# <Axes: xlabel='Country', ylabel='InAppPurchaseAmount'>

# %%
# Average spending by genre
plt.figure(figsize=(16, 6))
plt.xticks(rotation=30)
sns.barplot(data=MobileGame_DF, x='GameGenre', y='InAppPurchaseAmount', hue='GameGenre')
# Out:
# <Axes: xlabel='GameGenre', ylabel='InAppPurchaseAmount'>

# %%
# Box plot for when first purchase is made after install by game genre
plt.figure(figsize=(16, 6))
plt.xticks(rotation=30)
sns.boxplot(data=MobileGame_DF, x='GameGenre', y='FirstPurchaseDaysAfterInstall', hue='GameGenre')
# Out:
# <Axes: xlabel='GameGenre', ylabel='FirstPurchaseDaysAfterInstall'>
